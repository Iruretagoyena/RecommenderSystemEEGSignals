# %%
from google.colab import drive
drive.mount('/content/drive');
# Out:
# Mounted at /content/drive

# %%
ROOT_PATH = "/content/drive/Shareddrives/Proyecto RecSys 2021-2/Proyecto"

# %% [markdown]
# # Model

# %%
from tensorflow import keras
import tensorflow as tf
from tensorflow.keras import layers
from keras.layers.core import Dense, Dropout

# %%
SEQUENCE_LENGTH = 29
NUM_FEATURES = 1024

# %%
class PositionalEmbedding(layers.Layer):
    def __init__(self, sequence_length, output_dim, **kwargs):
        super().__init__(**kwargs)

        self.position_embeddings = layers.Embedding(
            input_dim=sequence_length, output_dim=output_dim
        )

        self.sequence_length = sequence_length
        self.output_dim = output_dim

    def call(self, inputs):
        # The inputs are of shape: `(batch_size, frames, num_features)`
        length = tf.shape(inputs)[1]
        positions = tf.range(start=0, limit=length, delta=1)
        embedded_positions = self.position_embeddings(positions)
        return inputs + embedded_positions

    def compute_mask(self, inputs, mask=None):
        mask = tf.reduce_any(tf.cast(inputs, "bool"), axis=-1)
        return mask

# %%
class TransformerEncoder(layers.Layer):
    def __init__(self, embed_dim, dense_dim, num_heads, **kwargs):
        super().__init__(**kwargs)

        self.embed_dim = embed_dim
        self.dense_dim = dense_dim
        self.num_heads = num_heads

        self.attention = layers.MultiHeadAttention(
            num_heads=num_heads,
            key_dim=embed_dim,
            dropout=0.3
        )

        self.dense_proj = keras.Sequential([
            Dense(dense_dim, activation=tf.nn.gelu),
            Dense(embed_dim)
        ])

        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()

    def call(self, inputs, mask=None):
        if mask is not None:
            mask = mask[:, tf.newaxis, :]

        attention_output = self.attention(inputs, inputs, attention_mask=mask)
        proj_input = self.layernorm_1(inputs + attention_output)
        proj_output = self.dense_proj(proj_input)
        return self.layernorm_2(proj_input + proj_output)

# %%
def build_transformer_model(
    dense_dim,
    num_heads,
    classes,
    dropout=0
):
    pos_emb = PositionalEmbedding(
        sequence_length=SEQUENCE_LENGTH,
        output_dim=NUM_FEATURES,
    )

    transf_enc = TransformerEncoder(
        embed_dim=NUM_FEATURES,
        dense_dim=dense_dim,
        num_heads=num_heads
    )

    head = Dense(classes, activation='softmax')

    inputs = keras.Input(shape=(None, None))
    embedded = pos_emb(inputs)

    x = transf_enc(embedded)
    x = layers.GlobalMaxPooling1D()(x)
    x = Dropout(dropout)(x)

    outputs = head(x)

    model = keras.Model(inputs, outputs)
    return model

# %%
def train_model(
    model,
    train_data,
    train_labels,
    checkpoint_path,
    batch_size=32
):
    checkpoint = keras.callbacks.ModelCheckpoint(
        checkpoint_path,
        save_weights_only=True,
        save_best_only=True,
        verbose=1
    )

    history = model.fit(
        train_data,
        train_labels,
        validation_split=VALIDATION_SPLIT, 
        epochs=EPOCHS,
        batch_size=batch_size, 
        callbacks=[checkpoint], 
        shuffle=True
    )

    return history

# %%
def predict_labels(model, data):
    pred = model(data)
    return tf.math.argmax(pred, axis=1).numpy()

# %%
# https://stackoverflow.com/questions/31324218/scikit-learn-how-to-obtain-true-positive-true-negative-false-positive-and-fal
def perf_measure(y_actual, y_hat):
    TP = 0
    FP = 0
    TN = 0
    FN = 0

    for i in range(len(y_hat)): 
        if y_actual[i] == y_hat[i] == 1:
           TP += 1
        if y_hat[i] == 1 and y_actual[i] != y_hat[i]:
           FP += 1
        if y_actual[i] == y_hat[i] == 0:
           TN += 1
        if y_hat[i] == 0 and y_actual[i] != y_hat[i]:
           FN += 1

    return(TP, FP, TN, FN)

# %% [markdown]
# # Data loading

# %%
FEATURES_PATH = f"{ROOT_PATH}/features-and-labels/features_all.npy"
LABELS_PATH = f"{ROOT_PATH}/features-and-labels/labels_all.npy"

# %%
import numpy as np


with open(FEATURES_PATH, 'rb') as file:
    features = np.load(file)

with open(LABELS_PATH, 'rb') as file:
    labels = np.load(file)

# %%
features.shape
# Out:
# (32, 40, 29, 1024)

# %%
labels.shape
# Out:
# (32, 40)

# %%
TEST_SIZE = 10
NUM_VIDEOS = 40

np.random.seed(0)

idxs = list(range(NUM_VIDEOS))

TEST_VIDEO_IDXS = np.random.choice(idxs, TEST_SIZE, replace=False)
TRAIN_VIDEO_IDXS = np.array([c for c in range(NUM_VIDEOS) if c not in TEST_VIDEO_IDXS])

# %%
TEST_VIDEO_IDXS
# Out:
# array([22, 20, 25,  4, 10, 15, 28, 11, 18, 29])

# %%
NUM_USERS = 32

user_train_features_dict, user_train_labels_dict = {}, {}
user_test_features_dict, user_test_labels_dict = {}, {}

for user in range(NUM_USERS):
    user_features = features[user, :, :, :]
    user_labels = labels[user, :]

    user_train_features = user_features[TRAIN_VIDEO_IDXS, :, :]
    user_test_features = user_features[TEST_VIDEO_IDXS, :, :]

    user_train_labels = np.expand_dims(user_labels[TRAIN_VIDEO_IDXS], axis=1)
    user_test_labels = np.expand_dims(user_labels[TEST_VIDEO_IDXS], axis=1)

    user_train_features_dict[user] = user_train_features
    user_test_features_dict[user] = user_test_features

    user_train_labels_dict[user] = user_train_labels
    user_test_labels_dict[user] = user_test_labels

# %%
print(user_train_features.shape)
print(user_test_features.shape)
print()
print(user_train_labels.shape)
print(user_test_labels.shape)
# Out:
# (30, 29, 1024)
# (10, 29, 1024)
#
# (30, 1)
# (10, 1)

# %% [markdown]
# ---

# %% [markdown]
# # Training

# %%
base_model_checkpoint_path = f"{ROOT_PATH}/models/transformer/checkpoints/base-model-weights.ckpt"
individual_model_checkpoint_path = lambda user: f"{ROOT_PATH}/models/transformer/checkpoints/user_{user}_model.ckpt"

# %%
dense_dim = 4096
num_heads = 1
classes = 2
dropout = 0.4

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate=1e-5)
loss = "sparse_categorical_crossentropy",
metrics = ["accuracy"]

EPOCHS = 5
VALIDATION_SPLIT = 4/30
BATCH_SIZE = 2

models_dict = {}
checkpoints_dict = {}

for user in range(NUM_USERS):
    print(f"\nTraining model for user {user}\n")
    checkpoint_path = individual_model_checkpoint_path(user)
    checkpoints_dict[user] = checkpoint_path

    train_features = user_train_features_dict[user]
    train_labels = user_train_labels_dict[user]

    model = build_transformer_model(
        dense_dim, 
        num_heads, 
        classes
    )

    model.load_weights(base_model_checkpoint_path);
    model.compile(
        optimizer=optimizer,
        loss=loss,
        metrics=metrics, 
    )

    train_model(
        model,
        train_features,
        train_labels,
        checkpoint_path, 
        batch_size=BATCH_SIZE
    )

    models_dict[user] = model
# Out:
# Epoch 1/10
# 13/13 [==============================] - ETA: 0s - loss: 0.7105 - accuracy: 0.6154
# Epoch 00001: val_loss improved from inf to 1.08378, saving model to /content/drive/Shareddrives/Proyecto RecSys 2021-2/Proyecto/models/transformer/checkpoints/user_0_model.ckpt
# 13/13 [==============================] - 3s 102ms/step - loss: 0.7105 - accuracy: 0.6154 - val_loss: 1.0838 - val_accuracy: 0.0000e+00
# Epoch 2/10
# 10/13 [======================>.......] - ETA: 0s - loss: 0.6765 - accuracy: 0.6500
# Epoch 00002: val_loss improved from 1.08378 to 0.50251, saving model to /content/drive/Shareddrives/Proyecto RecSys 2021-2/Proyecto/models/transformer/checkpoints/user_0_model.ckpt
# 13/13 [==============================] - 1s 77ms/step - loss: 0.6825 - accuracy: 0.6154 - val_loss: 0.5025 - val_accuracy: 1.0000
# Epoch 3/10
# 11/13 [========================>.....] - ETA: 0s - loss: 0.4991 - accuracy: 0.7273
# Epoch 00003: val_loss did not improve from 0.50251
# 13/13 [==============================] - 0s 20ms/step - loss: 0.4756 - accuracy: 0.7692 - val_loss: 0.7016 - val_accuracy: 0.7500
# Epoch 4/10
# 13/13 [==============================] - ETA: 0s - loss: 0.3680 - accuracy: 1.0000
# Epoch 00004: val_loss did not improve from 0.50251
# 13/13 [==============================] - 0s 19ms/step - loss: 0.3680 - accuracy: 1.0000 - val_loss: 1.1169 - val_accuracy: 0.0000e+00
# Epoch 5/10
# 13/13 [==============================] - ETA: 0s - loss: 0.3336 - accuracy: 0.8846
# Epoch 00005: val_loss improved from 0.50251 to 0.49504, saving model to /content/drive/Shareddrives/Proyecto RecSys 2021-2/Proyecto/models/transformer/checkpoints/user_0_model.ckpt
# 13/13 [==============================] - 1s 114ms/step - loss: 0.3336 - accuracy: 0.8846 - val_loss: 0.4950 - val_accuracy: 1.0000
# Epoch 6/10
# 13/13 [==============================] - ETA: 0s - loss: 0.2820 - accuracy: 1.0000
# Epoch 00006: val_loss did not improve from 0.49504
# 13/13 [==============================] - 0s 17ms/step - loss: 0.2820 - accuracy: 1.0000 - val_loss: 1.1381 - val_accuracy: 0.0000e+00
# Epoch 7/10
# 13/13 [==============================] - ETA: 0s - loss: 0.2535 - accuracy: 0.9231
# Epoch 00007: val_loss did not improve from 0.49504
# 13/13 [==============================] - 0s 17ms/step - loss: 0.2535 - accuracy: 0.9231 - val_loss: 0.5707 - val_accuracy: 0.7500
# Epoch 8/10
# 13/13 [==============================] - ETA: 0s - loss: 0.1991 - accuracy: 1.0000
# Epoch 00008: val_loss did not improve from 0.49504
# 13/13 [==============================] - 0s 19ms/step - loss: 0.1991 - accuracy: 1.0000 - val_loss: 1.1716 - val_accuracy: 0.0000e+00
# Epoch 9/10
# 12/13 [==========================>...] - ETA: 0s - loss: 0.1541 - accuracy: 1.0000
# Epoch 00009: val_loss did not improve from 0.49504
# 13/13 [==============================] - 0s 19ms/step - loss: 0.1579 - accuracy: 1.0000 - val_loss: 0.7063 - val_accuracy: 0.7500
# Epoch 10/10
# 13/13 [==============================] - ETA: 0s - loss: 0.1527 - accuracy: 1.0000
# Epoch 00010: val_loss did not improve from 0.49504
# 13/13 [==============================] - 0s 17ms/step - loss: 0.1527 - accuracy: 1.0000 - val_loss: 0.9429 - val_accuracy: 0.0000e+00
# Epoch 1/10
# 13/13 [==============================] - ETA: 0s - loss: 0.6409 - accuracy: 0.6538
# Epoch 00001: val_loss improved from inf to 0.84087, saving model to /content/drive/Shareddrives/Proyecto RecSys 2021-2/Proyecto/models/transformer/checkpoints/user_1_model.ckpt
# 13/13 [==============================] - 3s 98ms/step - loss: 0.6409 - accuracy: 0.6538 - val_loss: 0.8409 - val_accuracy: 0.2500
# Epoch 2/10
# 13/13 [==============================] - ETA: 0s - loss: 0.5239 - accuracy: 0.6923
# Epoch 00002: val_loss improved from 0.84087 to 0.67303, saving model to /content/drive/Shareddrives/Proyecto RecSys 2021-2/Proyecto/models/transformer/checkpoints/user_1_model.ckpt
# 13/13 [==============================] - 1s 73ms/step - loss: 0.5239 - accuracy: 0.6923 - val_loss: 0.6730 - val_accuracy: 0.7500
# Epoch 3/10
# 12/13 [==========================>...] - ETA: 0s - loss: 0.4205 - accuracy: 0.9167
# Epoch 00003: val_loss did not improve from 0.67303
# 13/13 [==============================] - 0s 20ms/step - loss: 0.4217 - accuracy: 0.8846 - val_loss: 0.9969 - val_accuracy: 0.2500
# Epoch 4/10
# 13/13 [==============================] - ETA: 0s - loss: 0.3536 - accuracy: 0.8846
# Epoch 00004: val_loss improved from 0.67303 to 0.56037, saving model to /content/drive/Shareddrives/Proyecto RecSys 2021-2/Proyecto/models/transformer/checkpoints/user_1_model.ckpt
# 13/13 [==============================] - 1s 114ms/step - loss: 0.3536 - accuracy: 0.8846 - val_loss: 0.5604 - val_accuracy: 0.7500
# Epoch 5/10
# 13/13 [==============================] - ETA: 0s - loss: 0.3541 - accuracy: 0.9231
# Epoch 00005: val_loss did not improve from 0.56037
# 13/13 [==============================] - 0s 18ms/step - loss: 0.3541 - accuracy: 0.9231 - val_loss: 1.1972 - val_accuracy: 0.2500
# Epoch 6/10
# 12/13 [==========================>...] - ETA: 0s - loss: 0.3133 - accuracy: 0.8750
# Epoch 00006: val_loss improved from 0.56037 to 0.55785, saving model to /content/drive/Shareddrives/Proyecto RecSys 2021-2/Proyecto/models/transformer/checkpoints/user_1_model.ckpt
# 13/13 [==============================] - 1s 98ms/step - loss: 0.3154 - accuracy: 0.8846 - val_loss: 0.5578 - val_accuracy: 0.7500
# Epoch 7/10
# 13/13 [==============================] - ETA: 0s - loss: 0.2222 - accuracy: 1.0000
# Epoch 00007: val_loss did not improve from 0.55785
# 13/13 [==============================] - 0s 22ms/step - loss: 0.2222 - accuracy: 1.0000 - val_loss: 1.3178 - val_accuracy: 0.2500
# Epoch 8/10
# 11/13 [========================>.....] - ETA: 0s - loss: 0.2424 - accuracy: 1.0000
# Epoch 00008: val_loss did not improve from 0.55785
# 13/13 [==============================] - 0s 20ms/step - loss: 0.2375 - accuracy: 1.0000 - val_loss: 0.7653 - val_accuracy: 0.2500
# Epoch 9/10
# 12/13 [==========================>...] - ETA: 0s - loss: 0.1686 - accuracy: 1.0000
# Epoch 00009: val_loss did not improve from 0.55785
# 13/13 [==============================] - 0s 22ms/step - loss: 0.1771 - accuracy: 1.0000 - val_loss: 1.0034 - val_accuracy: 0.2500
# Epoch 10/10
# 11/13 [========================>.....] - ETA: 0s - loss: 0.1637 - accuracy: 1.0000
# Epoch 00010: val_loss did not improve from 0.55785
# 13/13 [==============================] - 0s 22ms/step - loss: 0.1591 - accuracy: 1.0000 - val_loss: 0.8170 - val_accuracy: 0.2500
# Epoch 1/10
# 13/13 [==============================] - ETA: 0s - loss: 0.8303 - accuracy: 0.4231
# Epoch 00001: val_loss improved from inf to 0.41518, saving model to /content/drive/Shareddrives/Proyecto RecSys 2021-2/Proyecto/models/transformer/checkpoints/user_2_model.ckpt
# 13/13 [==============================] - 3s 96ms/step - loss: 0.8303 - accuracy: 0.4231 - val_loss: 0.4152 - val_accuracy: 1.0000
# Epoch 2/10
# 12/13 [==========================>...] - ETA: 0s - loss: 0.7869 - accuracy: 0.7083
# Epoch 00002: val_loss improved from 0.41518 to 0.40474, saving model to /content/drive/Shareddrives/Proyecto RecSys 2021-2/Proyecto/models/transformer/checkpoints/user_2_model.ckpt
# 13/13 [==============================] - 1s 114ms/step - loss: 0.7660 - accuracy: 0.7308 - val_loss: 0.4047 - val_accuracy: 1.0000
# Epoch 3/10
# 13/13 [==============================] - ETA: 0s - loss: 0.5201 - accuracy: 0.6538
# Epoch 00003: val_loss did not improve from 0.40474
# 13/13 [==============================] - 0s 18ms/step - loss: 0.5201 - accuracy: 0.6538 - val_loss: 0.6267 - val_accuracy: 0.7500
# Epoch 4/10
# 13/13 [==============================] - ETA: 0s - loss: 0.4268 - accuracy: 0.8846
# Epoch 00004: val_loss did not improve from 0.40474
# 13/13 [==============================] - 0s 18ms/step - loss: 0.4268 - accuracy: 0.8846 - val_loss: 0.5483 - val_accuracy: 1.0000
# Epoch 5/10
# 12/13 [==========================>...] - ETA: 0s - loss: 0.3437 - accuracy: 1.0000
# Epoch 00005: val_loss did not improve from 0.40474
# 13/13 [==============================] - 0s 19ms/step - loss: 0.3426 - accuracy: 1.0000 - val_loss: 0.6992 - val_accuracy: 0.5000
# Epoch 6/10
# 13/13 [==============================] - ETA: 0s - loss: 0.3117 - accuracy: 0.9615
# Epoch 00006: val_loss did not improve from 0.40474
# 13/13 [==============================] - 0s 16ms/step - loss: 0.3117 - accuracy: 0.9615 - val_loss: 0.8029 - val_accuracy: 0.2500
# Epoch 7/10
# 10/13 [======================>.......] - ETA: 0s - loss: 0.2939 - accuracy: 0.9500
# Epoch 00007: val_loss did not improve from 0.40474
# 13/13 [==============================] - 0s 15ms/step - loss: 0.2900 - accuracy: 0.9615 - val_loss: 0.4650 - val_accuracy: 1.0000
# Epoch 8/10
# 13/13 [==============================] - ETA: 0s - loss: 0.2461 - accuracy: 1.0000
# Epoch 00008: val_loss did not improve from 0.40474
# 13/13 [==============================] - 0s 17ms/step - loss: 0.2461 - accuracy: 1.0000 - val_loss: 0.6760 - val_accuracy: 0.5000
# Epoch 9/10
# 13/13 [==============================] - ETA: 0s - loss: 0.2001 - accuracy: 1.0000
# Epoch 00009: val_loss did not improve from 0.40474
# 13/13 [==============================] - 0s 17ms/step - loss: 0.2001 - accuracy: 1.0000 - val_loss: 0.7425 - val_accuracy: 0.5000
# Epoch 10/10
# 13/13 [==============================] - ETA: 0s - loss: 0.1798 - accuracy: 1.0000
# Epoch 00010: val_loss did not improve from 0.40474
# 13/13 [==============================] - 0s 17ms/step - loss: 0.1798 - accuracy: 1.0000 - val_loss: 0.6417 - val_accuracy: 0.5000
# Epoch 1/10
# 13/13 [==============================] - ETA: 0s - loss: 0.7084 - accuracy: 0.5385
# Epoch 00001: val_loss improved from inf to 0.74373, saving model to /content/drive/Shareddrives/Proyecto RecSys 2021-2/Proyecto/models/transformer/checkpoints/user_3_model.ckpt
# 13/13 [==============================] - 4s 142ms/step - loss: 0.7084 - accuracy: 0.5385 - val_loss: 0.7437 - val_accuracy: 0.5000
# Epoch 2/10
# 13/13 [==============================] - ETA: 0s - loss: 0.6135 - accuracy: 0.6538
# Epoch 00002: val_loss did not improve from 0.74373
# 13/13 [==============================] - 0s 17ms/step - loss: 0.6135 - accuracy: 0.6538 - val_loss: 0.9834 - val_accuracy: 0.0000e+00
# Epoch 3/10
# 13/13 [==============================] - ETA: 0s - loss: 0.6523 - accuracy: 0.5385
# Epoch 00003: val_loss did not improve from 0.74373
# 13/13 [==============================] - 0s 18ms/step - loss: 0.6523 - accuracy: 0.5385 - val_loss: 1.4352 - val_accuracy: 0.0000e+00
# Epoch 4/10
# 13/13 [==============================] - ETA: 0s - loss: 0.5208 - accuracy: 0.7308
# Epoch 00004: val_loss did not improve from 0.74373
# 13/13 [==============================] - 0s 15ms/step - loss: 0.5208 - accuracy: 0.7308 - val_loss: 1.0039 - val_accuracy: 0.0000e+00
# Epoch 5/10
# 13/13 [==============================] - ETA: 0s - loss: 0.3328 - accuracy: 1.0000
# Epoch 00005: val_loss improved from 0.74373 to 0.73133, saving model to /content/drive/Shareddrives/Proyecto RecSys 2021-2/Proyecto/models/transformer/checkpoints/user_3_model.ckpt
# 13/13 [==============================] - 1s 76ms/step - loss: 0.3328 - accuracy: 1.0000 - val_loss: 0.7313 - val_accuracy: 0.5000
# Epoch 6/10
# 13/13 [==============================] - ETA: 0s - loss: 0.2871 - accuracy: 0.9615
# Epoch 00006: val_loss improved from 0.73133 to 0.56695, saving model to /content/drive/Shareddrives/Proyecto RecSys 2021-2/Proyecto/models/transformer/checkpoints/user_3_model.ckpt
# 13/13 [==============================] - 1s 113ms/step - loss: 0.2871 - accuracy: 0.9615 - val_loss: 0.5669 - val_accuracy: 0.7500
# Epoch 7/10
# 13/13 [==============================] - ETA: 0s - loss: 0.2981 - accuracy: 1.0000
# Epoch 00007: val_loss did not improve from 0.56695
# 13/13 [==============================] - 0s 17ms/step - loss: 0.2981 - accuracy: 1.0000 - val_loss: 1.1512 - val_accuracy: 0.0000e+00
# Epoch 8/10
# 13/13 [==============================] - ETA: 0s - loss: 0.2410 - accuracy: 1.0000
# Epoch 00008: val_loss did not improve from 0.56695
# 13/13 [==============================] - 0s 19ms/step - loss: 0.2410 - accuracy: 1.0000 - val_loss: 0.6060 - val_accuracy: 0.7500
# Epoch 9/10
# 13/13 [==============================] - ETA: 0s - loss: 0.1921 - accuracy: 1.0000
# Epoch 00009: val_loss did not improve from 0.56695
# 13/13 [==============================] - 0s 18ms/step - loss: 0.1921 - accuracy: 1.0000 - val_loss: 0.7789 - val_accuracy: 0.2500
# Epoch 10/10
# 13/13 [==============================] - ETA: 0s - loss: 0.1662 - accuracy: 1.0000
# Epoch 00010: val_loss did not improve from 0.56695
# 13/13 [==============================] - 0s 17ms/step - loss: 0.1662 - accuracy: 1.0000 - val_loss: 0.6688 - val_accuracy: 0.7500
# Epoch 1/10
# 13/13 [==============================] - ETA: 0s - loss: 0.7008 - accuracy: 0.6154
# Epoch 00001: val_loss improved from inf to 0.85203, saving model to /content/drive/Shareddrives/Proyecto RecSys 2021-2/Proyecto/models/transformer/checkpoints/user_4_model.ckpt
# 13/13 [==============================] - 3s 142ms/step - loss: 0.7008 - accuracy: 0.6154 - val_loss: 0.8520 - val_accuracy: 0.0000e+00
# Epoch 2/10
# 12/13 [==========================>...] - ETA: 0s - loss: 0.7179 - accuracy: 0.6250
# Epoch 00002: val_loss did not improve from 0.85203
# 13/13 [==============================] - 0s 26ms/step - loss: 0.7044 - accuracy: 0.6154 - val_loss: 1.4157 - val_accuracy: 0.0000e+00
# Epoch 3/10
# 12/13 [==========================>...] - ETA: 0s - loss: 0.4877 - accuracy: 0.8750
# Epoch 00003: val_loss did not improve from 0.85203
# 13/13 [==============================] - 0s 19ms/step - loss: 0.4880 - accuracy: 0.8462 - val_loss: 1.6681 - val_accuracy: 0.0000e+00
# Epoch 4/10
# 13/13 [==============================] - ETA: 0s - loss: 0.4674 - accuracy: 0.7692
# Epoch 00004: val_loss did not improve from 0.85203
# 13/13 [==============================] - 0s 19ms/step - loss: 0.4674 - accuracy: 0.7692 - val_loss: 0.8632 - val_accuracy: 0.0000e+00
# Epoch 5/10
# 12/13 [==========================>...] - ETA: 0s - loss: 0.3209 - accuracy: 0.9167
# Epoch 00005: val_loss did not improve from 0.85203
# 13/13 [==============================] - 0s 21ms/step - loss: 0.3366 - accuracy: 0.8846 - val_loss: 1.7121 - val_accuracy: 0.0000e+00
# Epoch 6/10
# 13/13 [==============================] - ETA: 0s - loss: 0.2923 - accuracy: 1.0000
# Epoch 00006: val_loss did not improve from 0.85203
# 13/13 [==============================] - 0s 20ms/step - loss: 0.2923 - accuracy: 1.0000 - val_loss: 1.0724 - val_accuracy: 0.0000e+00
# Epoch 7/10
# 13/13 [==============================] - ETA: 0s - loss: 0.2445 - accuracy: 1.0000
# Epoch 00007: val_loss did not improve from 0.85203
# 13/13 [==============================] - 0s 26ms/step - loss: 0.2445 - accuracy: 1.0000 - val_loss: 1.4216 - val_accuracy: 0.0000e+00
# Epoch 8/10
# 11/13 [========================>.....] - ETA: 0s - loss: 0.2130 - accuracy: 1.0000
# Epoch 00008: val_loss did not improve from 0.85203
# 13/13 [==============================] - 0s 21ms/step - loss: 0.2185 - accuracy: 1.0000 - val_loss: 1.4711 - val_accuracy: 0.0000e+00
# Epoch 9/10
# 13/13 [==============================] - ETA: 0s - loss: 0.1925 - accuracy: 1.0000
# Epoch 00009: val_loss did not improve from 0.85203
# 13/13 [==============================] - 0s 21ms/step - loss: 0.1925 - accuracy: 1.0000 - val_loss: 1.4131 - val_accuracy: 0.0000e+00
# Epoch 10/10
# 13/13 [==============================] - ETA: 0s - loss: 0.1709 - accuracy: 1.0000
# Epoch 00010: val_loss did not improve from 0.85203
# 13/13 [==============================] - 0s 17ms/step - loss: 0.1709 - accuracy: 1.0000 - val_loss: 1.1932 - val_accuracy: 0.0000e+00
# Epoch 1/10
# 13/13 [==============================] - ETA: 0s - loss: 0.7599 - accuracy: 0.6538
# Epoch 00001: val_loss improved from inf to 0.65065, saving model to /content/drive/Shareddrives/Proyecto RecSys 2021-2/Proyecto/models/transformer/checkpoints/user_5_model.ckpt
# 13/13 [==============================] - 3s 102ms/step - loss: 0.7599 - accuracy: 0.6538 - val_loss: 0.6506 - val_accuracy: 0.5000
# Epoch 2/10
# 12/13 [==========================>...] - ETA: 0s - loss: 0.6881 - accuracy: 0.5833
# Epoch 00002: val_loss did not improve from 0.65065
# 13/13 [==============================] - 0s 18ms/step - loss: 0.7121 - accuracy: 0.5769 - val_loss: 1.7157 - val_accuracy: 0.2500
# Epoch 3/10
# 13/13 [==============================] - ETA: 0s - loss: 0.5488 - accuracy: 0.6923
# Epoch 00003: val_loss improved from 0.65065 to 0.57530, saving model to /content/drive/Shareddrives/Proyecto RecSys 2021-2/Proyecto/models/transformer/checkpoints/user_5_model.ckpt
# 13/13 [==============================] - 1s 108ms/step - loss: 0.5488 - accuracy: 0.6923 - val_loss: 0.5753 - val_accuracy: 1.0000
# Epoch 4/10
# 13/13 [==============================] - ETA: 0s - loss: 0.5819 - accuracy: 0.5769
# Epoch 00004: val_loss did not improve from 0.57530
# 13/13 [==============================] - 0s 26ms/step - loss: 0.5819 - accuracy: 0.5769 - val_loss: 1.5766 - val_accuracy: 0.2500
# Epoch 5/10
# 11/13 [========================>.....] - ETA: 0s - loss: 0.4414 - accuracy: 0.7273
# Epoch 00005: val_loss did not improve from 0.57530
# 13/13 [==============================] - 0s 22ms/step - loss: 0.4296 - accuracy: 0.7692 - val_loss: 0.6021 - val_accuracy: 0.7500
# Epoch 6/10
# 13/13 [==============================] - ETA: 0s - loss: 0.3170 - accuracy: 0.9615
# Epoch 00006: val_loss did not improve from 0.57530
# 13/13 [==============================] - 0s 25ms/step - loss: 0.3170 - accuracy: 0.9615 - val_loss: 1.2603 - val_accuracy: 0.2500
# Epoch 7/10
# 13/13 [==============================] - ETA: 0s - loss: 0.2273 - accuracy: 0.9231
# Epoch 00007: val_loss did not improve from 0.57530
# 13/13 [==============================] - 0s 21ms/step - loss: 0.2273 - accuracy: 0.9231 - val_loss: 0.7582 - val_accuracy: 0.5000
# Epoch 8/10
# 13/13 [==============================] - ETA: 0s - loss: 0.2012 - accuracy: 1.0000
# Epoch 00008: val_loss did not improve from 0.57530
# 13/13 [==============================] - 0s 21ms/step - loss: 0.2012 - accuracy: 1.0000 - val_loss: 1.0729 - val_accuracy: 0.2500
# Epoch 9/10
# 12/13 [==========================>...] - ETA: 0s - loss: 0.1795 - accuracy: 0.9583
# Epoch 00009: val_loss did not improve from 0.57530
# 13/13 [==============================] - 0s 21ms/step - loss: 0.1780 - accuracy: 0.9615 - val_loss: 0.9740 - val_accuracy: 0.2500
# Epoch 10/10
# 13/13 [==============================] - ETA: 0s - loss: 0.1545 - accuracy: 1.0000
# Epoch 00010: val_loss did not improve from 0.57530
# 13/13 [==============================] - 0s 26ms/step - loss: 0.1545 - accuracy: 1.0000 - val_loss: 0.8576 - val_accuracy: 0.2500
# Epoch 1/10
# 12/13 [==========================>...] - ETA: 0s - loss: 0.4476 - accuracy: 0.8750
# Epoch 00001: val_loss improved from inf to 0.56317, saving model to /content/drive/Shareddrives/Proyecto RecSys 2021-2/Proyecto/models/transformer/checkpoints/user_6_model.ckpt
# 13/13 [==============================] - 5s 191ms/step - loss: 0.4168 - accuracy: 0.8846 - val_loss: 0.5632 - val_accuracy: 0.7500
# Epoch 2/10
# 11/13 [========================>.....] - ETA: 0s - loss: 0.3055 - accuracy: 0.9091
# Epoch 00002: val_loss improved from 0.56317 to 0.42891, saving model to /content/drive/Shareddrives/Proyecto RecSys 2021-2/Proyecto/models/transformer/checkpoints/user_6_model.ckpt
# 13/13 [==============================] - 1s 93ms/step - loss: 0.3260 - accuracy: 0.8846 - val_loss: 0.4289 - val_accuracy: 0.7500
# Epoch 3/10
# 12/13 [==========================>...] - ETA: 0s - loss: 0.2511 - accuracy: 0.8750
# Epoch 00003: val_loss improved from 0.42891 to 0.40762, saving model to /content/drive/Shareddrives/Proyecto RecSys 2021-2/Proyecto/models/transformer/checkpoints/user_6_model.ckpt
# 13/13 [==============================] - 2s 124ms/step - loss: 0.2431 - accuracy: 0.8846 - val_loss: 0.4076 - val_accuracy: 0.7500
# Epoch 4/10
# 13/13 [==============================] - ETA: 0s - loss: 0.1987 - accuracy: 0.9231
# Epoch 00004: val_loss did not improve from 0.40762
# 13/13 [==============================] - 0s 24ms/step - loss: 0.1987 - accuracy: 0.9231 - val_loss: 0.5469 - val_accuracy: 0.7500
# Epoch 5/10
# 11/13 [========================>.....] - ETA: 0s - loss: 0.1640 - accuracy: 0.8636
# Epoch 00005: val_loss improved from 0.40762 to 0.40753, saving model to /content/drive/Shareddrives/Proyecto RecSys 2021-2/Proyecto/models/transformer/checkpoints/user_6_model.ckpt
# 13/13 [==============================] - 1s 102ms/step - loss: 0.1562 - accuracy: 0.8846 - val_loss: 0.4075 - val_accuracy: 0.7500
# Epoch 6/10
# 11/13 [========================>.....] - ETA: 0s - loss: 0.1086 - accuracy: 1.0000
# Epoch 00006: val_loss did not improve from 0.40753
# 13/13 [==============================] - 0s 21ms/step - loss: 0.1319 - accuracy: 0.9615 - val_loss: 0.5725 - val_accuracy: 0.7500
# Epoch 7/10
# 12/13 [==========================>...] - ETA: 0s - loss: 0.1179 - accuracy: 0.9583
# Epoch 00007: val_loss did not improve from 0.40753
# 13/13 [==============================] - 0s 18ms/step - loss: 0.1144 - accuracy: 0.9615 - val_loss: 0.4471 - val_accuracy: 0.7500
# Epoch 8/10
# 13/13 [==============================] - ETA: 0s - loss: 0.0889 - accuracy: 1.0000
# Epoch 00008: val_loss did not improve from 0.40753
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0889 - accuracy: 1.0000 - val_loss: 0.6040 - val_accuracy: 0.7500
# Epoch 9/10
# 13/13 [==============================] - ETA: 0s - loss: 0.0656 - accuracy: 1.0000
# Epoch 00009: val_loss did not improve from 0.40753
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0656 - accuracy: 1.0000 - val_loss: 0.5589 - val_accuracy: 0.7500
# Epoch 10/10
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0551 - accuracy: 1.0000
# Epoch 00010: val_loss did not improve from 0.40753
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0596 - accuracy: 1.0000 - val_loss: 0.5856 - val_accuracy: 0.7500
# Epoch 1/10
# 13/13 [==============================] - ETA: 0s - loss: 0.8253 - accuracy: 0.5769
# Epoch 00001: val_loss improved from inf to 0.55738, saving model to /content/drive/Shareddrives/Proyecto RecSys 2021-2/Proyecto/models/transformer/checkpoints/user_7_model.ckpt
# 13/13 [==============================] - 3s 104ms/step - loss: 0.8253 - accuracy: 0.5769 - val_loss: 0.5574 - val_accuracy: 0.7500
# Epoch 2/10
# 12/13 [==========================>...] - ETA: 0s - loss: 0.7083 - accuracy: 0.6250
# Epoch 00002: val_loss did not improve from 0.55738
# 13/13 [==============================] - 0s 19ms/step - loss: 0.7123 - accuracy: 0.6154 - val_loss: 1.3489 - val_accuracy: 0.0000e+00
# Epoch 3/10
# 12/13 [==========================>...] - ETA: 0s - loss: 0.5022 - accuracy: 0.7083
# Epoch 00003: val_loss did not improve from 0.55738
# 13/13 [==============================] - 0s 18ms/step - loss: 0.4949 - accuracy: 0.7308 - val_loss: 0.5951 - val_accuracy: 0.5000
# Epoch 4/10
# 12/13 [==========================>...] - ETA: 0s - loss: 0.3679 - accuracy: 0.9583
# Epoch 00004: val_loss did not improve from 0.55738
# 13/13 [==============================] - 0s 19ms/step - loss: 0.3536 - accuracy: 0.9615 - val_loss: 1.2374 - val_accuracy: 0.0000e+00
# Epoch 5/10
# 13/13 [==============================] - ETA: 0s - loss: 0.3127 - accuracy: 0.9231
# Epoch 00005: val_loss did not improve from 0.55738
# 13/13 [==============================] - 0s 18ms/step - loss: 0.3127 - accuracy: 0.9231 - val_loss: 1.1348 - val_accuracy: 0.0000e+00
# Epoch 6/10
# 13/13 [==============================] - ETA: 0s - loss: 0.2477 - accuracy: 1.0000
# Epoch 00006: val_loss did not improve from 0.55738
# 13/13 [==============================] - 0s 18ms/step - loss: 0.2477 - accuracy: 1.0000 - val_loss: 0.8967 - val_accuracy: 0.2500
# Epoch 7/10
# 13/13 [==============================] - ETA: 0s - loss: 0.2249 - accuracy: 1.0000
# Epoch 00007: val_loss did not improve from 0.55738
# 13/13 [==============================] - 0s 18ms/step - loss: 0.2249 - accuracy: 1.0000 - val_loss: 0.8188 - val_accuracy: 0.5000
# Epoch 8/10
# 13/13 [==============================] - ETA: 0s - loss: 0.1961 - accuracy: 1.0000
# Epoch 00008: val_loss did not improve from 0.55738
# 13/13 [==============================] - 0s 16ms/step - loss: 0.1961 - accuracy: 1.0000 - val_loss: 0.9204 - val_accuracy: 0.2500
# Epoch 9/10
# 13/13 [==============================] - ETA: 0s - loss: 0.1630 - accuracy: 1.0000
# Epoch 00009: val_loss did not improve from 0.55738
# 13/13 [==============================] - 0s 17ms/step - loss: 0.1630 - accuracy: 1.0000 - val_loss: 1.1622 - val_accuracy: 0.0000e+00
# Epoch 10/10
# 13/13 [==============================] - ETA: 0s - loss: 0.1488 - accuracy: 1.0000
# Epoch 00010: val_loss did not improve from 0.55738
# 13/13 [==============================] - 0s 17ms/step - loss: 0.1488 - accuracy: 1.0000 - val_loss: 1.0320 - val_accuracy: 0.0000e+00
# Epoch 1/10
# 13/13 [==============================] - ETA: 0s - loss: 0.7773 - accuracy: 0.5769
# Epoch 00001: val_loss improved from inf to 1.06309, saving model to /content/drive/Shareddrives/Proyecto RecSys 2021-2/Proyecto/models/transformer/checkpoints/user_8_model.ckpt
# 13/13 [==============================] - 3s 140ms/step - loss: 0.7773 - accuracy: 0.5769 - val_loss: 1.0631 - val_accuracy: 0.2500
# Epoch 2/10
# 12/13 [==========================>...] - ETA: 0s - loss: 0.6380 - accuracy: 0.6250
# Epoch 00002: val_loss improved from 1.06309 to 0.65825, saving model to /content/drive/Shareddrives/Proyecto RecSys 2021-2/Proyecto/models/transformer/checkpoints/user_8_model.ckpt
# 13/13 [==============================] - 1s 110ms/step - loss: 0.6040 - accuracy: 0.6538 - val_loss: 0.6583 - val_accuracy: 0.7500
# Epoch 3/10
# 11/13 [========================>.....] - ETA: 0s - loss: 0.5817 - accuracy: 0.6818
# Epoch 00003: val_loss did not improve from 0.65825
# 13/13 [==============================] - 0s 20ms/step - loss: 0.5997 - accuracy: 0.6923 - val_loss: 0.8956 - val_accuracy: 0.5000
# Epoch 4/10
# 12/13 [==========================>...] - ETA: 0s - loss: 0.4753 - accuracy: 0.7917
# Epoch 00004: val_loss did not improve from 0.65825
# 13/13 [==============================] - 0s 19ms/step - loss: 0.4733 - accuracy: 0.8077 - val_loss: 0.6604 - val_accuracy: 0.7500
# Epoch 5/10
# 13/13 [==============================] - ETA: 0s - loss: 0.4220 - accuracy: 0.8462
# Epoch 00005: val_loss improved from 0.65825 to 0.64342, saving model to /content/drive/Shareddrives/Proyecto RecSys 2021-2/Proyecto/models/transformer/checkpoints/user_8_model.ckpt
# 13/13 [==============================] - 1s 79ms/step - loss: 0.4220 - accuracy: 0.8462 - val_loss: 0.6434 - val_accuracy: 0.7500
# Epoch 6/10
# 13/13 [==============================] - ETA: 0s - loss: 0.3296 - accuracy: 0.8462
# Epoch 00006: val_loss did not improve from 0.64342
# 13/13 [==============================] - 0s 17ms/step - loss: 0.3296 - accuracy: 0.8462 - val_loss: 0.7562 - val_accuracy: 0.2500
# Epoch 7/10
# 12/13 [==========================>...] - ETA: 0s - loss: 0.2905 - accuracy: 1.0000
# Epoch 00007: val_loss did not improve from 0.64342
# 13/13 [==============================] - 0s 19ms/step - loss: 0.2882 - accuracy: 1.0000 - val_loss: 0.6661 - val_accuracy: 0.7500
# Epoch 8/10
# 12/13 [==========================>...] - ETA: 0s - loss: 0.2532 - accuracy: 1.0000
# Epoch 00008: val_loss did not improve from 0.64342
# 13/13 [==============================] - 0s 17ms/step - loss: 0.2472 - accuracy: 1.0000 - val_loss: 0.7247 - val_accuracy: 0.5000
# Epoch 9/10
# 13/13 [==============================] - ETA: 0s - loss: 0.1972 - accuracy: 1.0000
# Epoch 00009: val_loss did not improve from 0.64342
# 13/13 [==============================] - 0s 17ms/step - loss: 0.1972 - accuracy: 1.0000 - val_loss: 0.6801 - val_accuracy: 0.7500
# Epoch 10/10
# 13/13 [==============================] - ETA: 0s - loss: 0.1749 - accuracy: 1.0000
# Epoch 00010: val_loss did not improve from 0.64342
# 13/13 [==============================] - 0s 17ms/step - loss: 0.1749 - accuracy: 1.0000 - val_loss: 0.6955 - val_accuracy: 0.5000
# Epoch 1/10
# 13/13 [==============================] - ETA: 0s - loss: 0.8384 - accuracy: 0.5000
# Epoch 00001: val_loss improved from inf to 0.57646, saving model to /content/drive/Shareddrives/Proyecto RecSys 2021-2/Proyecto/models/transformer/checkpoints/user_9_model.ckpt
# 13/13 [==============================] - 3s 136ms/step - loss: 0.8384 - accuracy: 0.5000 - val_loss: 0.5765 - val_accuracy: 0.7500
# Epoch 2/10
# 13/13 [==============================] - ETA: 0s - loss: 0.8117 - accuracy: 0.5000
# Epoch 00002: val_loss did not improve from 0.57646
# 13/13 [==============================] - 0s 18ms/step - loss: 0.8117 - accuracy: 0.5000 - val_loss: 0.6500 - val_accuracy: 0.5000
# Epoch 3/10
# 10/13 [======================>.......] - ETA: 0s - loss: 0.5461 - accuracy: 0.6000
# Epoch 00003: val_loss did not improve from 0.57646
# 13/13 [==============================] - 0s 17ms/step - loss: 0.5183 - accuracy: 0.6538 - val_loss: 1.1646 - val_accuracy: 0.2500
# Epoch 4/10
# 13/13 [==============================] - ETA: 0s - loss: 0.3662 - accuracy: 0.8077
# Epoch 00004: val_loss did not improve from 0.57646
# 13/13 [==============================] - 0s 17ms/step - loss: 0.3662 - accuracy: 0.8077 - val_loss: 0.7083 - val_accuracy: 0.7500
# Epoch 5/10
# 13/13 [==============================] - ETA: 0s - loss: 0.3072 - accuracy: 0.9615
# Epoch 00005: val_loss did not improve from 0.57646
# 13/13 [==============================] - 0s 17ms/step - loss: 0.3072 - accuracy: 0.9615 - val_loss: 0.9555 - val_accuracy: 0.2500
# Epoch 6/10
# 13/13 [==============================] - ETA: 0s - loss: 0.2357 - accuracy: 1.0000
# Epoch 00006: val_loss did not improve from 0.57646
# 13/13 [==============================] - 0s 18ms/step - loss: 0.2357 - accuracy: 1.0000 - val_loss: 0.8027 - val_accuracy: 0.2500
# Epoch 7/10
# 13/13 [==============================] - ETA: 0s - loss: 0.1970 - accuracy: 1.0000
# Epoch 00007: val_loss did not improve from 0.57646
# 13/13 [==============================] - 0s 17ms/step - loss: 0.1970 - accuracy: 1.0000 - val_loss: 0.9876 - val_accuracy: 0.2500
# Epoch 8/10
# 11/13 [========================>.....] - ETA: 0s - loss: 0.1799 - accuracy: 1.0000
# Epoch 00008: val_loss did not improve from 0.57646
# 13/13 [==============================] - 0s 33ms/step - loss: 0.1809 - accuracy: 1.0000 - val_loss: 0.9571 - val_accuracy: 0.2500
# Epoch 9/10
# 12/13 [==========================>...] - ETA: 0s - loss: 0.1547 - accuracy: 1.0000
# Epoch 00009: val_loss did not improve from 0.57646
# 13/13 [==============================] - 1s 44ms/step - loss: 0.1578 - accuracy: 1.0000 - val_loss: 0.8157 - val_accuracy: 0.2500
# Epoch 10/10
# 13/13 [==============================] - ETA: 0s - loss: 0.1553 - accuracy: 1.0000
# Epoch 00010: val_loss did not improve from 0.57646
# 13/13 [==============================] - 0s 36ms/step - loss: 0.1553 - accuracy: 1.0000 - val_loss: 0.8984 - val_accuracy: 0.2500
# Epoch 1/10
# 13/13 [==============================] - ETA: 0s - loss: 0.7056 - accuracy: 0.5769
# Epoch 00001: val_loss improved from inf to 1.34539, saving model to /content/drive/Shareddrives/Proyecto RecSys 2021-2/Proyecto/models/transformer/checkpoints/user_10_model.ckpt
# 13/13 [==============================] - 3s 97ms/step - loss: 0.7056 - accuracy: 0.5769 - val_loss: 1.3454 - val_accuracy: 0.2500
# Epoch 2/10
# 12/13 [==========================>...] - ETA: 0s - loss: 0.6000 - accuracy: 0.6667
# Epoch 00002: val_loss improved from 1.34539 to 1.00087, saving model to /content/drive/Shareddrives/Proyecto RecSys 2021-2/Proyecto/models/transformer/checkpoints/user_10_model.ckpt
# 13/13 [==============================] - 1s 105ms/step - loss: 0.5933 - accuracy: 0.6538 - val_loss: 1.0009 - val_accuracy: 0.2500
# Epoch 3/10
# 11/13 [========================>.....] - ETA: 0s - loss: 0.5203 - accuracy: 0.8182
# Epoch 00003: val_loss did not improve from 1.00087
# 13/13 [==============================] - 0s 26ms/step - loss: 0.5343 - accuracy: 0.8077 - val_loss: 1.1835 - val_accuracy: 0.2500
# Epoch 4/10
# 13/13 [==============================] - ETA: 0s - loss: 0.5525 - accuracy: 0.7308
# Epoch 00004: val_loss improved from 1.00087 to 0.74019, saving model to /content/drive/Shareddrives/Proyecto RecSys 2021-2/Proyecto/models/transformer/checkpoints/user_10_model.ckpt
# 13/13 [==============================] - 2s 139ms/step - loss: 0.5525 - accuracy: 0.7308 - val_loss: 0.7402 - val_accuracy: 0.5000
# Epoch 5/10
# 13/13 [==============================] - ETA: 0s - loss: 0.3971 - accuracy: 0.9231
# Epoch 00005: val_loss did not improve from 0.74019
# 13/13 [==============================] - 0s 18ms/step - loss: 0.3971 - accuracy: 0.9231 - val_loss: 1.5076 - val_accuracy: 0.2500
# Epoch 6/10
# 13/13 [==============================] - ETA: 0s - loss: 0.3297 - accuracy: 0.9231
# Epoch 00006: val_loss did not improve from 0.74019
# 13/13 [==============================] - 0s 17ms/step - loss: 0.3297 - accuracy: 0.9231 - val_loss: 1.0498 - val_accuracy: 0.2500
# Epoch 7/10
# 13/13 [==============================] - ETA: 0s - loss: 0.2726 - accuracy: 1.0000
# Epoch 00007: val_loss did not improve from 0.74019
# 13/13 [==============================] - 0s 16ms/step - loss: 0.2726 - accuracy: 1.0000 - val_loss: 1.0048 - val_accuracy: 0.2500
# Epoch 8/10
# 13/13 [==============================] - ETA: 0s - loss: 0.2498 - accuracy: 1.0000
# Epoch 00008: val_loss did not improve from 0.74019
# 13/13 [==============================] - 0s 17ms/step - loss: 0.2498 - accuracy: 1.0000 - val_loss: 1.2818 - val_accuracy: 0.2500
# Epoch 9/10
# 13/13 [==============================] - ETA: 0s - loss: 0.2586 - accuracy: 1.0000
# Epoch 00009: val_loss did not improve from 0.74019
# 13/13 [==============================] - 0s 17ms/step - loss: 0.2586 - accuracy: 1.0000 - val_loss: 0.9205 - val_accuracy: 0.5000
# Epoch 10/10
# 13/13 [==============================] - ETA: 0s - loss: 0.1996 - accuracy: 1.0000
# Epoch 00010: val_loss did not improve from 0.74019
# 13/13 [==============================] - 0s 16ms/step - loss: 0.1996 - accuracy: 1.0000 - val_loss: 1.5385 - val_accuracy: 0.2500
# Epoch 1/10
# 13/13 [==============================] - ETA: 0s - loss: 0.6868 - accuracy: 0.5769
# Epoch 00001: val_loss improved from inf to 0.48461, saving model to /content/drive/Shareddrives/Proyecto RecSys 2021-2/Proyecto/models/transformer/checkpoints/user_11_model.ckpt
# 13/13 [==============================] - 3s 101ms/step - loss: 0.6868 - accuracy: 0.5769 - val_loss: 0.4846 - val_accuracy: 1.0000
# Epoch 2/10
# 13/13 [==============================] - ETA: 0s - loss: 0.5212 - accuracy: 0.6923
# Epoch 00002: val_loss did not improve from 0.48461
# 13/13 [==============================] - 0s 17ms/step - loss: 0.5212 - accuracy: 0.6923 - val_loss: 0.8867 - val_accuracy: 0.2500
# Epoch 3/10
# 12/13 [==========================>...] - ETA: 0s - loss: 0.3784 - accuracy: 0.9583
# Epoch 00003: val_loss did not improve from 0.48461
# 13/13 [==============================] - 0s 18ms/step - loss: 0.3812 - accuracy: 0.9615 - val_loss: 0.7002 - val_accuracy: 0.5000
# Epoch 4/10
# 13/13 [==============================] - ETA: 0s - loss: 0.3096 - accuracy: 1.0000
# Epoch 00004: val_loss did not improve from 0.48461
# 13/13 [==============================] - 0s 18ms/step - loss: 0.3096 - accuracy: 1.0000 - val_loss: 0.6685 - val_accuracy: 0.5000
# Epoch 5/10
# 13/13 [==============================] - ETA: 0s - loss: 0.2606 - accuracy: 1.0000
# Epoch 00005: val_loss did not improve from 0.48461
# 13/13 [==============================] - 0s 18ms/step - loss: 0.2606 - accuracy: 1.0000 - val_loss: 0.8123 - val_accuracy: 0.2500
# Epoch 6/10
# 13/13 [==============================] - ETA: 0s - loss: 0.2720 - accuracy: 1.0000
# Epoch 00006: val_loss did not improve from 0.48461
# 13/13 [==============================] - 0s 16ms/step - loss: 0.2720 - accuracy: 1.0000 - val_loss: 0.6519 - val_accuracy: 0.5000
# Epoch 7/10
# 13/13 [==============================] - ETA: 0s - loss: 0.2084 - accuracy: 1.0000
# Epoch 00007: val_loss did not improve from 0.48461
# 13/13 [==============================] - 0s 17ms/step - loss: 0.2084 - accuracy: 1.0000 - val_loss: 0.6746 - val_accuracy: 0.5000
# Epoch 8/10
# 13/13 [==============================] - ETA: 0s - loss: 0.1746 - accuracy: 1.0000
# Epoch 00008: val_loss did not improve from 0.48461
# 13/13 [==============================] - 0s 16ms/step - loss: 0.1746 - accuracy: 1.0000 - val_loss: 0.7702 - val_accuracy: 0.5000
# Epoch 9/10
# 13/13 [==============================] - ETA: 0s - loss: 0.1410 - accuracy: 1.0000
# Epoch 00009: val_loss did not improve from 0.48461
# 13/13 [==============================] - 0s 17ms/step - loss: 0.1410 - accuracy: 1.0000 - val_loss: 0.7321 - val_accuracy: 0.5000
# Epoch 10/10
#  9/13 [===================>..........] - ETA: 0s - loss: 0.1530 - accuracy: 1.0000
# Epoch 00010: val_loss did not improve from 0.48461
# 13/13 [==============================] - 0s 15ms/step - loss: 0.1451 - accuracy: 1.0000 - val_loss: 0.8401 - val_accuracy: 0.2500
# Epoch 1/10
# 13/13 [==============================] - ETA: 0s - loss: 0.8956 - accuracy: 0.5385
# Epoch 00001: val_loss improved from inf to 0.40420, saving model to /content/drive/Shareddrives/Proyecto RecSys 2021-2/Proyecto/models/transformer/checkpoints/user_12_model.ckpt
# 13/13 [==============================] - 4s 144ms/step - loss: 0.8956 - accuracy: 0.5385 - val_loss: 0.4042 - val_accuracy: 0.7500
# Epoch 2/10
# 11/13 [========================>.....] - ETA: 0s - loss: 0.4462 - accuracy: 0.8636
# Epoch 00002: val_loss did not improve from 0.40420
# 13/13 [==============================] - 0s 21ms/step - loss: 0.6376 - accuracy: 0.7692 - val_loss: 1.4436 - val_accuracy: 0.2500
# Epoch 3/10
# 13/13 [==============================] - ETA: 0s - loss: 0.4246 - accuracy: 0.8462
# Epoch 00003: val_loss did not improve from 0.40420
# 13/13 [==============================] - 0s 18ms/step - loss: 0.4246 - accuracy: 0.8462 - val_loss: 0.4388 - val_accuracy: 1.0000
# Epoch 4/10
# 13/13 [==============================] - ETA: 0s - loss: 0.2992 - accuracy: 0.9231
# Epoch 00004: val_loss did not improve from 0.40420
# 13/13 [==============================] - 0s 18ms/step - loss: 0.2992 - accuracy: 0.9231 - val_loss: 1.0554 - val_accuracy: 0.2500
# Epoch 5/10
# 13/13 [==============================] - ETA: 0s - loss: 0.2846 - accuracy: 0.8077
# Epoch 00005: val_loss did not improve from 0.40420
# 13/13 [==============================] - 0s 19ms/step - loss: 0.2846 - accuracy: 0.8077 - val_loss: 0.5678 - val_accuracy: 0.7500
# Epoch 6/10
# 12/13 [==========================>...] - ETA: 0s - loss: 0.2647 - accuracy: 1.0000
# Epoch 00006: val_loss did not improve from 0.40420
# 13/13 [==============================] - 0s 18ms/step - loss: 0.2650 - accuracy: 1.0000 - val_loss: 0.7717 - val_accuracy: 0.5000
# Epoch 7/10
# 12/13 [==========================>...] - ETA: 0s - loss: 0.2126 - accuracy: 1.0000
# Epoch 00007: val_loss did not improve from 0.40420
# 13/13 [==============================] - 0s 18ms/step - loss: 0.2069 - accuracy: 1.0000 - val_loss: 0.7657 - val_accuracy: 0.5000
# Epoch 8/10
# 12/13 [==========================>...] - ETA: 0s - loss: 0.1791 - accuracy: 1.0000
# Epoch 00008: val_loss did not improve from 0.40420
# 13/13 [==============================] - 0s 19ms/step - loss: 0.1859 - accuracy: 1.0000 - val_loss: 0.8383 - val_accuracy: 0.2500
# Epoch 9/10
# 13/13 [==============================] - ETA: 0s - loss: 0.1576 - accuracy: 1.0000
# Epoch 00009: val_loss did not improve from 0.40420
# 13/13 [==============================] - 0s 18ms/step - loss: 0.1576 - accuracy: 1.0000 - val_loss: 0.7399 - val_accuracy: 0.5000
# Epoch 10/10
# 13/13 [==============================] - ETA: 0s - loss: 0.1551 - accuracy: 1.0000
# Epoch 00010: val_loss did not improve from 0.40420
# 13/13 [==============================] - 0s 17ms/step - loss: 0.1551 - accuracy: 1.0000 - val_loss: 0.9377 - val_accuracy: 0.2500
# Epoch 1/10
# 12/13 [==========================>...] - ETA: 0s - loss: 0.7196 - accuracy: 0.6667
# Epoch 00001: val_loss improved from inf to 0.79563, saving model to /content/drive/Shareddrives/Proyecto RecSys 2021-2/Proyecto/models/transformer/checkpoints/user_13_model.ckpt
# 13/13 [==============================] - 3s 109ms/step - loss: 0.7032 - accuracy: 0.6538 - val_loss: 0.7956 - val_accuracy: 0.2500
# Epoch 2/10
# 12/13 [==========================>...] - ETA: 0s - loss: 0.6006 - accuracy: 0.6250
# Epoch 00002: val_loss did not improve from 0.79563
# 13/13 [==============================] - 0s 19ms/step - loss: 0.5697 - accuracy: 0.6538 - val_loss: 1.4491 - val_accuracy: 0.0000e+00
# Epoch 3/10
# 12/13 [==========================>...] - ETA: 0s - loss: 0.4796 - accuracy: 0.7500
# Epoch 00003: val_loss improved from 0.79563 to 0.44489, saving model to /content/drive/Shareddrives/Proyecto RecSys 2021-2/Proyecto/models/transformer/checkpoints/user_13_model.ckpt
# 13/13 [==============================] - 1s 120ms/step - loss: 0.4989 - accuracy: 0.7308 - val_loss: 0.4449 - val_accuracy: 1.0000
# Epoch 4/10
# 13/13 [==============================] - ETA: 0s - loss: 0.3894 - accuracy: 0.8462
# Epoch 00004: val_loss did not improve from 0.44489
# 13/13 [==============================] - 0s 20ms/step - loss: 0.3894 - accuracy: 0.8462 - val_loss: 1.2011 - val_accuracy: 0.0000e+00
# Epoch 5/10
# 12/13 [==========================>...] - ETA: 0s - loss: 0.3133 - accuracy: 1.0000
# Epoch 00005: val_loss did not improve from 0.44489
# 13/13 [==============================] - 0s 19ms/step - loss: 0.3057 - accuracy: 1.0000 - val_loss: 0.9782 - val_accuracy: 0.0000e+00
# Epoch 6/10
# 13/13 [==============================] - ETA: 0s - loss: 0.2553 - accuracy: 1.0000
# Epoch 00006: val_loss did not improve from 0.44489
# 13/13 [==============================] - 0s 18ms/step - loss: 0.2553 - accuracy: 1.0000 - val_loss: 1.0295 - val_accuracy: 0.0000e+00
# Epoch 7/10
# 13/13 [==============================] - ETA: 0s - loss: 0.2179 - accuracy: 1.0000
# Epoch 00007: val_loss did not improve from 0.44489
# 13/13 [==============================] - 0s 17ms/step - loss: 0.2179 - accuracy: 1.0000 - val_loss: 0.8639 - val_accuracy: 0.2500
# Epoch 8/10
# 13/13 [==============================] - ETA: 0s - loss: 0.2082 - accuracy: 1.0000
# Epoch 00008: val_loss did not improve from 0.44489
# 13/13 [==============================] - 0s 18ms/step - loss: 0.2082 - accuracy: 1.0000 - val_loss: 1.1207 - val_accuracy: 0.0000e+00
# Epoch 9/10
# 13/13 [==============================] - ETA: 0s - loss: 0.1678 - accuracy: 1.0000
# Epoch 00009: val_loss did not improve from 0.44489
# 13/13 [==============================] - 0s 18ms/step - loss: 0.1678 - accuracy: 1.0000 - val_loss: 0.9360 - val_accuracy: 0.2500
# Epoch 10/10
#  9/13 [===================>..........] - ETA: 0s - loss: 0.1411 - accuracy: 1.0000
# Epoch 00010: val_loss did not improve from 0.44489
# 13/13 [==============================] - 0s 15ms/step - loss: 0.1538 - accuracy: 1.0000 - val_loss: 0.8736 - val_accuracy: 0.2500
# Epoch 1/10
# 13/13 [==============================] - ETA: 0s - loss: 0.6551 - accuracy: 0.6538
# Epoch 00001: val_loss improved from inf to 1.23416, saving model to /content/drive/Shareddrives/Proyecto RecSys 2021-2/Proyecto/models/transformer/checkpoints/user_14_model.ckpt
# 13/13 [==============================] - 3s 134ms/step - loss: 0.6551 - accuracy: 0.6538 - val_loss: 1.2342 - val_accuracy: 0.0000e+00
# Epoch 2/10
# 13/13 [==============================] - ETA: 0s - loss: 0.5180 - accuracy: 0.6923
# Epoch 00002: val_loss did not improve from 1.23416
# 13/13 [==============================] - 0s 19ms/step - loss: 0.5180 - accuracy: 0.6923 - val_loss: 1.3068 - val_accuracy: 0.0000e+00
# Epoch 3/10
# 13/13 [==============================] - ETA: 0s - loss: 0.5392 - accuracy: 0.6923
# Epoch 00003: val_loss improved from 1.23416 to 0.85480, saving model to /content/drive/Shareddrives/Proyecto RecSys 2021-2/Proyecto/models/transformer/checkpoints/user_14_model.ckpt
# 13/13 [==============================] - 1s 80ms/step - loss: 0.5392 - accuracy: 0.6923 - val_loss: 0.8548 - val_accuracy: 0.2500
# Epoch 4/10
# 13/13 [==============================] - ETA: 0s - loss: 0.4726 - accuracy: 0.8077
# Epoch 00004: val_loss did not improve from 0.85480
# 13/13 [==============================] - 0s 18ms/step - loss: 0.4726 - accuracy: 0.8077 - val_loss: 1.6760 - val_accuracy: 0.0000e+00
# Epoch 5/10
# 12/13 [==========================>...] - ETA: 0s - loss: 0.3372 - accuracy: 0.7500
# Epoch 00005: val_loss improved from 0.85480 to 0.66050, saving model to /content/drive/Shareddrives/Proyecto RecSys 2021-2/Proyecto/models/transformer/checkpoints/user_14_model.ckpt
# 13/13 [==============================] - 1s 77ms/step - loss: 0.3231 - accuracy: 0.7692 - val_loss: 0.6605 - val_accuracy: 0.7500
# Epoch 6/10
# 13/13 [==============================] - ETA: 0s - loss: 0.2227 - accuracy: 1.0000
# Epoch 00006: val_loss did not improve from 0.66050
# 13/13 [==============================] - 0s 18ms/step - loss: 0.2227 - accuracy: 1.0000 - val_loss: 1.0103 - val_accuracy: 0.0000e+00
# Epoch 7/10
# 13/13 [==============================] - ETA: 0s - loss: 0.1845 - accuracy: 1.0000
# Epoch 00007: val_loss did not improve from 0.66050
# 13/13 [==============================] - 0s 18ms/step - loss: 0.1845 - accuracy: 1.0000 - val_loss: 0.9976 - val_accuracy: 0.0000e+00
# Epoch 8/10
# 12/13 [==========================>...] - ETA: 0s - loss: 0.1457 - accuracy: 1.0000
# Epoch 00008: val_loss did not improve from 0.66050
# 13/13 [==============================] - 0s 19ms/step - loss: 0.1573 - accuracy: 1.0000 - val_loss: 1.2539 - val_accuracy: 0.0000e+00
# Epoch 9/10
# 13/13 [==============================] - ETA: 0s - loss: 0.1502 - accuracy: 1.0000
# Epoch 00009: val_loss did not improve from 0.66050
# 13/13 [==============================] - 0s 22ms/step - loss: 0.1502 - accuracy: 1.0000 - val_loss: 0.9314 - val_accuracy: 0.0000e+00
# Epoch 10/10
# 11/13 [========================>.....] - ETA: 0s - loss: 0.1241 - accuracy: 1.0000
# Epoch 00010: val_loss did not improve from 0.66050
# 13/13 [==============================] - 0s 24ms/step - loss: 0.1175 - accuracy: 1.0000 - val_loss: 1.1439 - val_accuracy: 0.0000e+00
# Epoch 1/10
# 13/13 [==============================] - ETA: 0s - loss: 0.8201 - accuracy: 0.4231
# Epoch 00001: val_loss improved from inf to 0.69197, saving model to /content/drive/Shareddrives/Proyecto RecSys 2021-2/Proyecto/models/transformer/checkpoints/user_15_model.ckpt
# 13/13 [==============================] - 3s 136ms/step - loss: 0.8201 - accuracy: 0.4231 - val_loss: 0.6920 - val_accuracy: 0.5000
# Epoch 2/10
# 13/13 [==============================] - ETA: 0s - loss: 0.5450 - accuracy: 0.7692
# Epoch 00002: val_loss did not improve from 0.69197
# 13/13 [==============================] - 0s 19ms/step - loss: 0.5450 - accuracy: 0.7692 - val_loss: 0.7166 - val_accuracy: 0.5000
# Epoch 3/10
# 11/13 [========================>.....] - ETA: 0s - loss: 0.3972 - accuracy: 0.9545
# Epoch 00003: val_loss did not improve from 0.69197
# 13/13 [==============================] - 0s 29ms/step - loss: 0.4038 - accuracy: 0.9615 - val_loss: 1.5352 - val_accuracy: 0.0000e+00
# Epoch 4/10
# 11/13 [========================>.....] - ETA: 0s - loss: 0.4229 - accuracy: 0.8182
# Epoch 00004: val_loss improved from 0.69197 to 0.44107, saving model to /content/drive/Shareddrives/Proyecto RecSys 2021-2/Proyecto/models/transformer/checkpoints/user_15_model.ckpt
# 13/13 [==============================] - 1s 107ms/step - loss: 0.4272 - accuracy: 0.8077 - val_loss: 0.4411 - val_accuracy: 1.0000
# Epoch 5/10
# 13/13 [==============================] - ETA: 0s - loss: 0.3031 - accuracy: 1.0000
# Epoch 00005: val_loss did not improve from 0.44107
# 13/13 [==============================] - 0s 23ms/step - loss: 0.3031 - accuracy: 1.0000 - val_loss: 1.4085 - val_accuracy: 0.0000e+00
# Epoch 6/10
# 11/13 [========================>.....] - ETA: 0s - loss: 0.2775 - accuracy: 0.9545
# Epoch 00006: val_loss did not improve from 0.44107
# 13/13 [==============================] - 0s 21ms/step - loss: 0.2906 - accuracy: 0.9615 - val_loss: 0.6490 - val_accuracy: 0.7500
# Epoch 7/10
# 12/13 [==========================>...] - ETA: 0s - loss: 0.2097 - accuracy: 1.0000
# Epoch 00007: val_loss did not improve from 0.44107
# ...
# Epoch 00010: val_loss did not improve from 0.31877
# 13/13 [==============================] - 0s 18ms/step - loss: 0.1417 - accuracy: 1.0000 - val_loss: 0.7804 - val_accuracy: 0.5000
# Epoch 1/10
# 13/13 [==============================] - ETA: 0s - loss: 0.8344 - accuracy: 0.5769
# Epoch 00001: val_loss improved from inf to 0.60335, saving model to /content/drive/Shareddrives/Proyecto RecSys 2021-2/Proyecto/models/transformer/checkpoints/user_27_model.ckpt
# 13/13 [==============================] - 3s 104ms/step - loss: 0.8344 - accuracy: 0.5769 - val_loss: 0.6033 - val_accuracy: 0.7500
# Epoch 2/10
# 12/13 [==========================>...] - ETA: 0s - loss: 0.5893 - accuracy: 0.6250
# Epoch 00002: val_loss did not improve from 0.60335
# 13/13 [==============================] - 0s 20ms/step - loss: 0.6290 - accuracy: 0.6154 - val_loss: 2.1471 - val_accuracy: 0.2500
# Epoch 3/10
# 13/13 [==============================] - ETA: 0s - loss: 0.6676 - accuracy: 0.7308
# Epoch 00003: val_loss improved from 0.60335 to 0.52320, saving model to /content/drive/Shareddrives/Proyecto RecSys 2021-2/Proyecto/models/transformer/checkpoints/user_27_model.ckpt
# 13/13 [==============================] - 1s 81ms/step - loss: 0.6676 - accuracy: 0.7308 - val_loss: 0.5232 - val_accuracy: 1.0000
# Epoch 4/10
# 13/13 [==============================] - ETA: 0s - loss: 0.5586 - accuracy: 0.7692
# Epoch 00004: val_loss did not improve from 0.52320
# 13/13 [==============================] - 0s 19ms/step - loss: 0.5586 - accuracy: 0.7692 - val_loss: 1.5804 - val_accuracy: 0.2500
# Epoch 5/10
# 13/13 [==============================] - ETA: 0s - loss: 0.2937 - accuracy: 0.9615
# Epoch 00005: val_loss did not improve from 0.52320
# 13/13 [==============================] - 0s 19ms/step - loss: 0.2937 - accuracy: 0.9615 - val_loss: 0.6833 - val_accuracy: 0.2500
# Epoch 6/10
# 13/13 [==============================] - ETA: 0s - loss: 0.2866 - accuracy: 0.9615
# Epoch 00006: val_loss did not improve from 0.52320
# 13/13 [==============================] - 0s 18ms/step - loss: 0.2866 - accuracy: 0.9615 - val_loss: 1.5491 - val_accuracy: 0.2500
# Epoch 7/10
# 13/13 [==============================] - ETA: 0s - loss: 0.2752 - accuracy: 0.8462
# Epoch 00007: val_loss did not improve from 0.52320
# 13/13 [==============================] - 0s 18ms/step - loss: 0.2752 - accuracy: 0.8462 - val_loss: 0.7711 - val_accuracy: 0.2500
# Epoch 8/10
# 12/13 [==========================>...] - ETA: 0s - loss: 0.2238 - accuracy: 0.9583
# Epoch 00008: val_loss did not improve from 0.52320
# 13/13 [==============================] - 0s 19ms/step - loss: 0.2435 - accuracy: 0.9615 - val_loss: 1.5758 - val_accuracy: 0.2500
# Epoch 9/10
# 13/13 [==============================] - ETA: 0s - loss: 0.1894 - accuracy: 1.0000
# Epoch 00009: val_loss did not improve from 0.52320
# 13/13 [==============================] - 0s 18ms/step - loss: 0.1894 - accuracy: 1.0000 - val_loss: 0.8517 - val_accuracy: 0.2500
# Epoch 10/10
# 12/13 [==========================>...] - ETA: 0s - loss: 0.1684 - accuracy: 1.0000
# Epoch 00010: val_loss did not improve from 0.52320
# 13/13 [==============================] - 0s 19ms/step - loss: 0.1629 - accuracy: 1.0000 - val_loss: 1.3086 - val_accuracy: 0.2500
# Epoch 1/10
# 13/13 [==============================] - ETA: 0s - loss: 0.5287 - accuracy: 0.6538
# Epoch 00001: val_loss improved from inf to 1.74226, saving model to /content/drive/Shareddrives/Proyecto RecSys 2021-2/Proyecto/models/transformer/checkpoints/user_28_model.ckpt
# 13/13 [==============================] - 5s 164ms/step - loss: 0.5287 - accuracy: 0.6538 - val_loss: 1.7423 - val_accuracy: 0.5000
# Epoch 2/10
# 11/13 [========================>.....] - ETA: 0s - loss: 0.9429 - accuracy: 0.7727
# Epoch 00002: val_loss improved from 1.74226 to 0.85353, saving model to /content/drive/Shareddrives/Proyecto RecSys 2021-2/Proyecto/models/transformer/checkpoints/user_28_model.ckpt
# 13/13 [==============================] - 1s 95ms/step - loss: 0.9853 - accuracy: 0.6923 - val_loss: 0.8535 - val_accuracy: 0.5000
# Epoch 3/10
# 13/13 [==============================] - ETA: 0s - loss: 0.5404 - accuracy: 0.6923
# Epoch 00003: val_loss did not improve from 0.85353
# 13/13 [==============================] - 0s 17ms/step - loss: 0.5404 - accuracy: 0.6923 - val_loss: 1.0964 - val_accuracy: 0.5000
# Epoch 4/10
# 13/13 [==============================] - ETA: 0s - loss: 0.3560 - accuracy: 0.7308
# Epoch 00004: val_loss improved from 0.85353 to 0.81311, saving model to /content/drive/Shareddrives/Proyecto RecSys 2021-2/Proyecto/models/transformer/checkpoints/user_28_model.ckpt
# 13/13 [==============================] - 1s 81ms/step - loss: 0.3560 - accuracy: 0.7308 - val_loss: 0.8131 - val_accuracy: 0.5000
# Epoch 5/10
# 12/13 [==========================>...] - ETA: 0s - loss: 0.2474 - accuracy: 1.0000
# Epoch 00005: val_loss did not improve from 0.81311
# 13/13 [==============================] - 0s 18ms/step - loss: 0.2705 - accuracy: 0.9615 - val_loss: 0.9024 - val_accuracy: 0.5000
# Epoch 6/10
# 13/13 [==============================] - ETA: 0s - loss: 0.2154 - accuracy: 1.0000
# Epoch 00006: val_loss improved from 0.81311 to 0.77646, saving model to /content/drive/Shareddrives/Proyecto RecSys 2021-2/Proyecto/models/transformer/checkpoints/user_28_model.ckpt
# 13/13 [==============================] - 1s 82ms/step - loss: 0.2154 - accuracy: 1.0000 - val_loss: 0.7765 - val_accuracy: 0.5000
# Epoch 7/10
# 13/13 [==============================] - ETA: 0s - loss: 0.1874 - accuracy: 1.0000
# Epoch 00007: val_loss did not improve from 0.77646
# 13/13 [==============================] - 0s 19ms/step - loss: 0.1874 - accuracy: 1.0000 - val_loss: 0.8692 - val_accuracy: 0.5000
# Epoch 8/10
# 13/13 [==============================] - ETA: 0s - loss: 0.1623 - accuracy: 1.0000
# Epoch 00008: val_loss did not improve from 0.77646
# 13/13 [==============================] - 0s 18ms/step - loss: 0.1623 - accuracy: 1.0000 - val_loss: 0.9907 - val_accuracy: 0.5000
# Epoch 9/10
# 13/13 [==============================] - ETA: 0s - loss: 0.1503 - accuracy: 1.0000
# Epoch 00009: val_loss did not improve from 0.77646
# 13/13 [==============================] - 0s 18ms/step - loss: 0.1503 - accuracy: 1.0000 - val_loss: 0.8555 - val_accuracy: 0.5000
# Epoch 10/10
# 12/13 [==========================>...] - ETA: 0s - loss: 0.1259 - accuracy: 1.0000
# Epoch 00010: val_loss did not improve from 0.77646
# 13/13 [==============================] - 0s 20ms/step - loss: 0.1284 - accuracy: 1.0000 - val_loss: 0.9891 - val_accuracy: 0.5000
# Epoch 1/10
# 13/13 [==============================] - ETA: 0s - loss: 0.8483 - accuracy: 0.4615
# Epoch 00001: val_loss improved from inf to 1.14187, saving model to /content/drive/Shareddrives/Proyecto RecSys 2021-2/Proyecto/models/transformer/checkpoints/user_29_model.ckpt
# 13/13 [==============================] - 3s 144ms/step - loss: 0.8483 - accuracy: 0.4615 - val_loss: 1.1419 - val_accuracy: 0.2500
# Epoch 2/10
# 12/13 [==========================>...] - ETA: 0s - loss: 0.7309 - accuracy: 0.4583
# Epoch 00002: val_loss improved from 1.14187 to 1.02459, saving model to /content/drive/Shareddrives/Proyecto RecSys 2021-2/Proyecto/models/transformer/checkpoints/user_29_model.ckpt
# 13/13 [==============================] - 1s 117ms/step - loss: 0.7432 - accuracy: 0.4615 - val_loss: 1.0246 - val_accuracy: 0.2500
# Epoch 3/10
# 12/13 [==========================>...] - ETA: 0s - loss: 0.5524 - accuracy: 0.7083
# Epoch 00003: val_loss improved from 1.02459 to 0.78311, saving model to /content/drive/Shareddrives/Proyecto RecSys 2021-2/Proyecto/models/transformer/checkpoints/user_29_model.ckpt
# 13/13 [==============================] - 1s 79ms/step - loss: 0.5442 - accuracy: 0.7308 - val_loss: 0.7831 - val_accuracy: 0.5000
# Epoch 4/10
# 13/13 [==============================] - ETA: 0s - loss: 0.4180 - accuracy: 0.9615
# Epoch 00004: val_loss did not improve from 0.78311
# 13/13 [==============================] - 0s 18ms/step - loss: 0.4180 - accuracy: 0.9615 - val_loss: 0.8779 - val_accuracy: 0.2500
# Epoch 5/10
# 13/13 [==============================] - ETA: 0s - loss: 0.3589 - accuracy: 1.0000
# Epoch 00005: val_loss improved from 0.78311 to 0.75090, saving model to /content/drive/Shareddrives/Proyecto RecSys 2021-2/Proyecto/models/transformer/checkpoints/user_29_model.ckpt
# 13/13 [==============================] - 1s 80ms/step - loss: 0.3589 - accuracy: 1.0000 - val_loss: 0.7509 - val_accuracy: 0.5000
# Epoch 6/10
# 13/13 [==============================] - ETA: 0s - loss: 0.3029 - accuracy: 1.0000
# Epoch 00006: val_loss did not improve from 0.75090
# 13/13 [==============================] - 0s 20ms/step - loss: 0.3029 - accuracy: 1.0000 - val_loss: 1.0331 - val_accuracy: 0.2500
# Epoch 7/10
# 13/13 [==============================] - ETA: 0s - loss: 0.2872 - accuracy: 1.0000
# Epoch 00007: val_loss did not improve from 0.75090
# 13/13 [==============================] - 0s 19ms/step - loss: 0.2872 - accuracy: 1.0000 - val_loss: 0.8540 - val_accuracy: 0.5000
# Epoch 8/10
# 13/13 [==============================] - ETA: 0s - loss: 0.2485 - accuracy: 1.0000
# Epoch 00008: val_loss did not improve from 0.75090
# 13/13 [==============================] - 0s 18ms/step - loss: 0.2485 - accuracy: 1.0000 - val_loss: 0.9030 - val_accuracy: 0.2500
# Epoch 9/10
# 13/13 [==============================] - ETA: 0s - loss: 0.2597 - accuracy: 1.0000
# Epoch 00009: val_loss improved from 0.75090 to 0.72657, saving model to /content/drive/Shareddrives/Proyecto RecSys 2021-2/Proyecto/models/transformer/checkpoints/user_29_model.ckpt
# 13/13 [==============================] - 1s 114ms/step - loss: 0.2597 - accuracy: 1.0000 - val_loss: 0.7266 - val_accuracy: 0.2500
# Epoch 10/10
# 12/13 [==========================>...] - ETA: 0s - loss: 0.1944 - accuracy: 1.0000
# Epoch 00010: val_loss did not improve from 0.72657
# 13/13 [==============================] - 0s 20ms/step - loss: 0.1891 - accuracy: 1.0000 - val_loss: 0.8398 - val_accuracy: 0.5000
# Epoch 1/10
# 12/13 [==========================>...] - ETA: 0s - loss: 0.5974 - accuracy: 0.7083
# Epoch 00001: val_loss improved from inf to 1.49896, saving model to /content/drive/Shareddrives/Proyecto RecSys 2021-2/Proyecto/models/transformer/checkpoints/user_30_model.ckpt
# 13/13 [==============================] - 3s 98ms/step - loss: 0.5699 - accuracy: 0.7308 - val_loss: 1.4990 - val_accuracy: 0.0000e+00
# Epoch 2/10
# 12/13 [==========================>...] - ETA: 0s - loss: 0.4880 - accuracy: 0.7500
# Epoch 00002: val_loss improved from 1.49896 to 1.35701, saving model to /content/drive/Shareddrives/Proyecto RecSys 2021-2/Proyecto/models/transformer/checkpoints/user_30_model.ckpt
# 13/13 [==============================] - 1s 82ms/step - loss: 0.4788 - accuracy: 0.7692 - val_loss: 1.3570 - val_accuracy: 0.0000e+00
# Epoch 3/10
# 12/13 [==========================>...] - ETA: 0s - loss: 0.3414 - accuracy: 0.9167
# Epoch 00003: val_loss did not improve from 1.35701
# 13/13 [==============================] - 0s 18ms/step - loss: 0.3517 - accuracy: 0.8846 - val_loss: 2.1059 - val_accuracy: 0.0000e+00
# Epoch 4/10
# 13/13 [==============================] - ETA: 0s - loss: 0.3139 - accuracy: 0.7692
# Epoch 00004: val_loss improved from 1.35701 to 0.76595, saving model to /content/drive/Shareddrives/Proyecto RecSys 2021-2/Proyecto/models/transformer/checkpoints/user_30_model.ckpt
# 13/13 [==============================] - 1s 116ms/step - loss: 0.3139 - accuracy: 0.7692 - val_loss: 0.7659 - val_accuracy: 0.5000
# Epoch 5/10
# 12/13 [==========================>...] - ETA: 0s - loss: 0.2262 - accuracy: 1.0000
# Epoch 00005: val_loss did not improve from 0.76595
# 13/13 [==============================] - 0s 19ms/step - loss: 0.2473 - accuracy: 0.9615 - val_loss: 2.5998 - val_accuracy: 0.0000e+00
# Epoch 6/10
# 12/13 [==========================>...] - ETA: 0s - loss: 0.2607 - accuracy: 0.8750
# Epoch 00006: val_loss did not improve from 0.76595
# 13/13 [==============================] - 0s 18ms/step - loss: 0.2533 - accuracy: 0.8846 - val_loss: 1.1679 - val_accuracy: 0.0000e+00
# Epoch 7/10
# 13/13 [==============================] - ETA: 0s - loss: 0.1683 - accuracy: 1.0000
# Epoch 00007: val_loss did not improve from 0.76595
# 13/13 [==============================] - 0s 19ms/step - loss: 0.1683 - accuracy: 1.0000 - val_loss: 1.8808 - val_accuracy: 0.0000e+00
# Epoch 8/10
# 11/13 [========================>.....] - ETA: 0s - loss: 0.1253 - accuracy: 1.0000
# Epoch 00008: val_loss did not improve from 0.76595
# 13/13 [==============================] - 0s 19ms/step - loss: 0.1230 - accuracy: 1.0000 - val_loss: 1.4448 - val_accuracy: 0.0000e+00
# Epoch 9/10
# 11/13 [========================>.....] - ETA: 0s - loss: 0.1071 - accuracy: 1.0000
# Epoch 00009: val_loss did not improve from 0.76595
# 13/13 [==============================] - 0s 18ms/step - loss: 0.1069 - accuracy: 1.0000 - val_loss: 1.8277 - val_accuracy: 0.0000e+00
# Epoch 10/10
# 12/13 [==========================>...] - ETA: 0s - loss: 0.1033 - accuracy: 1.0000
# Epoch 00010: val_loss did not improve from 0.76595
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0995 - accuracy: 1.0000 - val_loss: 1.6713 - val_accuracy: 0.0000e+00
# Epoch 1/10
# 13/13 [==============================] - ETA: 0s - loss: 0.8408 - accuracy: 0.5385
# Epoch 00001: val_loss improved from inf to 0.45703, saving model to /content/drive/Shareddrives/Proyecto RecSys 2021-2/Proyecto/models/transformer/checkpoints/user_31_model.ckpt
# 13/13 [==============================] - 3s 117ms/step - loss: 0.8408 - accuracy: 0.5385 - val_loss: 0.4570 - val_accuracy: 1.0000
# Epoch 2/10
# 12/13 [==========================>...] - ETA: 0s - loss: 0.7185 - accuracy: 0.6250
# Epoch 00002: val_loss did not improve from 0.45703
# 13/13 [==============================] - 0s 26ms/step - loss: 0.7036 - accuracy: 0.6154 - val_loss: 1.2834 - val_accuracy: 0.0000e+00
# Epoch 3/10
# 12/13 [==========================>...] - ETA: 0s - loss: 0.5129 - accuracy: 0.7917
# Epoch 00003: val_loss did not improve from 0.45703
# 13/13 [==============================] - 0s 24ms/step - loss: 0.5142 - accuracy: 0.8077 - val_loss: 1.0104 - val_accuracy: 0.0000e+00
# Epoch 4/10
# 11/13 [========================>.....] - ETA: 0s - loss: 0.4128 - accuracy: 0.8182
# Epoch 00004: val_loss did not improve from 0.45703
# 13/13 [==============================] - 0s 24ms/step - loss: 0.4244 - accuracy: 0.8462 - val_loss: 0.8191 - val_accuracy: 0.2500
# Epoch 5/10
# 13/13 [==============================] - ETA: 0s - loss: 0.3456 - accuracy: 1.0000
# Epoch 00005: val_loss did not improve from 0.45703
# 13/13 [==============================] - 0s 23ms/step - loss: 0.3456 - accuracy: 1.0000 - val_loss: 1.0578 - val_accuracy: 0.0000e+00
# Epoch 6/10
# 13/13 [==============================] - ETA: 0s - loss: 0.2894 - accuracy: 1.0000
# Epoch 00006: val_loss did not improve from 0.45703
# 13/13 [==============================] - 0s 17ms/step - loss: 0.2894 - accuracy: 1.0000 - val_loss: 1.2796 - val_accuracy: 0.0000e+00
# Epoch 7/10
# 13/13 [==============================] - ETA: 0s - loss: 0.2384 - accuracy: 1.0000
# Epoch 00007: val_loss did not improve from 0.45703
# 13/13 [==============================] - 0s 19ms/step - loss: 0.2384 - accuracy: 1.0000 - val_loss: 1.0216 - val_accuracy: 0.2500
# Epoch 8/10
# 13/13 [==============================] - ETA: 0s - loss: 0.2358 - accuracy: 1.0000
# Epoch 00008: val_loss did not improve from 0.45703
# 13/13 [==============================] - 0s 19ms/step - loss: 0.2358 - accuracy: 1.0000 - val_loss: 0.8430 - val_accuracy: 0.2500
# Epoch 9/10
# 13/13 [==============================] - ETA: 0s - loss: 0.2027 - accuracy: 1.0000
# Epoch 00009: val_loss did not improve from 0.45703
# 13/13 [==============================] - 0s 18ms/step - loss: 0.2027 - accuracy: 1.0000 - val_loss: 1.2970 - val_accuracy: 0.0000e+00
# Epoch 10/10
# 12/13 [==========================>...] - ETA: 0s - loss: 0.1612 - accuracy: 1.0000
# Epoch 00010: val_loss did not improve from 0.45703
# 13/13 [==============================] - 0s 19ms/step - loss: 0.1710 - accuracy: 1.0000 - val_loss: 1.2971 - val_accuracy: 0.0000e+00

# %%
for user, model in models_dict.items():
    print(f"Model for user {user}")

    model.load_weights(checkpoints_dict[user])
    loss, accuracy = model.evaluate(user_test_features_dict[user], user_test_labels_dict[user])

    print(f"Test accuracy: {accuracy:.2f}")
    print()
# Out:
# Model for user 0
# 1/1 [==============================] - 1s 622ms/step - loss: 0.5932 - accuracy: 0.7000
# Test accuracy: 0.70
#
# Model for user 1
# 1/1 [==============================] - 1s 582ms/step - loss: 0.8706 - accuracy: 0.3000
# Test accuracy: 0.30
#
# Model for user 2
# 1/1 [==============================] - 1s 581ms/step - loss: 1.0045 - accuracy: 0.2000
# Test accuracy: 0.20
#
# Model for user 3
# WARNING:tensorflow:5 out of the last 24 calls to <function Model.make_test_function.<locals>.test_function at 0x7f4a908fb9e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 329ms/step - loss: 0.6395 - accuracy: 0.7000
# Test accuracy: 0.70
#
# Model for user 4
# WARNING:tensorflow:6 out of the last 25 calls to <function Model.make_test_function.<locals>.test_function at 0x7f4a90a28dd0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 358ms/step - loss: 0.7241 - accuracy: 0.5000
# Test accuracy: 0.50
#
# Model for user 5
# 1/1 [==============================] - 0s 335ms/step - loss: 0.7419 - accuracy: 0.5000
# Test accuracy: 0.50
#
# Model for user 6
# 1/1 [==============================] - 0s 329ms/step - loss: 0.4276 - accuracy: 0.9000
# Test accuracy: 0.90
#
# Model for user 7
# 1/1 [==============================] - 0s 331ms/step - loss: 0.7982 - accuracy: 0.3000
# Test accuracy: 0.30
#
# Model for user 8
# 1/1 [==============================] - 0s 358ms/step - loss: 0.9226 - accuracy: 0.5000
# Test accuracy: 0.50
#
# Model for user 9
# 1/1 [==============================] - 0s 357ms/step - loss: 0.8595 - accuracy: 0.2000
# Test accuracy: 0.20
#
# Model for user 10
# 1/1 [==============================] - 0s 326ms/step - loss: 0.6660 - accuracy: 0.7000
# Test accuracy: 0.70
#
# Model for user 11
# 1/1 [==============================] - 0s 336ms/step - loss: 0.7298 - accuracy: 0.3000
# Test accuracy: 0.30
#
# Model for user 12
# 1/1 [==============================] - 0s 331ms/step - loss: 1.0263 - accuracy: 0.2000
# Test accuracy: 0.20
#
# Model for user 13
# 1/1 [==============================] - 0s 354ms/step - loss: 0.8660 - accuracy: 0.2000
# Test accuracy: 0.20
#
# Model for user 14
# 1/1 [==============================] - 0s 334ms/step - loss: 0.5868 - accuracy: 0.6000
# Test accuracy: 0.60
#
# Model for user 15
# 1/1 [==============================] - 0s 332ms/step - loss: 0.9110 - accuracy: 0.4000
# Test accuracy: 0.40
#
# Model for user 16
# 1/1 [==============================] - 0s 349ms/step - loss: 0.8442 - accuracy: 0.4000
# Test accuracy: 0.40
#
# Model for user 17
# 1/1 [==============================] - 0s 338ms/step - loss: 0.8739 - accuracy: 0.2000
# Test accuracy: 0.20
#
# Model for user 18
# 1/1 [==============================] - 0s 343ms/step - loss: 0.7125 - accuracy: 0.4000
# Test accuracy: 0.40
#
# Model for user 19
# 1/1 [==============================] - 0s 359ms/step - loss: 0.6939 - accuracy: 0.7000
# Test accuracy: 0.70
#
# Model for user 20
# 1/1 [==============================] - 0s 349ms/step - loss: 0.4898 - accuracy: 0.9000
# Test accuracy: 0.90
#
# Model for user 21
# 1/1 [==============================] - 0s 350ms/step - loss: 1.1677 - accuracy: 0.2000
# Test accuracy: 0.20
#
# Model for user 22
# 1/1 [==============================] - 0s 340ms/step - loss: 0.7080 - accuracy: 0.6000
# Test accuracy: 0.60
#
# Model for user 23
# 1/1 [==============================] - 0s 329ms/step - loss: 0.7109 - accuracy: 0.5000
# Test accuracy: 0.50
#
# Model for user 24
# 1/1 [==============================] - 0s 351ms/step - loss: 0.7414 - accuracy: 0.4000
# Test accuracy: 0.40
#
# Model for user 25
# 1/1 [==============================] - 0s 321ms/step - loss: 0.6823 - accuracy: 0.5000
# Test accuracy: 0.50
#
# Model for user 26
# 1/1 [==============================] - 0s 321ms/step - loss: 0.7898 - accuracy: 0.3000
# Test accuracy: 0.30
#
# Model for user 27
# 1/1 [==============================] - 0s 331ms/step - loss: 0.6252 - accuracy: 0.8000
# Test accuracy: 0.80
#
# Model for user 28
# 1/1 [==============================] - 0s 329ms/step - loss: 1.0094 - accuracy: 0.5000
# Test accuracy: 0.50
#
# Model for user 29
# 1/1 [==============================] - 0s 343ms/step - loss: 0.6709 - accuracy: 0.5000
# Test accuracy: 0.50
#
# Model for user 30
# 1/1 [==============================] - 0s 332ms/step - loss: 0.7883 - accuracy: 0.4000
# Test accuracy: 0.40
#
# Model for user 31
# 1/1 [==============================] - 0s 370ms/step - loss: 0.8698 - accuracy: 0.4000
# Test accuracy: 0.40

# %% [markdown]
# ---
